# %% [markdown]
# <a href="https://colab.research.google.com/github/railergodthatlikesvanilla/cs1-python-gold-diuyan/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Please enter number 1 "))
num2 = int(input("Please enter number 2 "))
num3 = int(input("Please enter number 3 "))
if num1 > num2 and num1 > num3:
    print("The largest number is", num1)
elif num2 > num1 and num2 > num3:
    print("The largest number is", num2)
else:
    print("The l4argest number is", num3)
# Out:
# Please enter number 1 534
# Please enter number 2 53454
# Please enter number 3 54353
# The l4argest number is 54353
